# %%
import pandas as pd
import FinanceDataReader as fdr

# %%
fdr.__version__
# Out:
# '0.9.20'

# %% [markdown]
# ### 한국거래소 상장종목 전체 가져오기

# %%
# 도움말은 ? , 소스코드를 보고 싶으면 ??
fdr.StockListing??
# Out:
# Signature: fdr.StockListing(market)
# Source:
# def StockListing(market):
#     '''
#     read stock list of stock exchanges
#     market: 'S&P500', 'NASDAQ', 'NYSE', 'AMEX', 'SSE', 'SZSE', 'HKEX', 'TSE', 'HOSE',
#             'KRX', 'KOSPI', 'KOSDAQ', 'KONEX'
#             'KRX-DELISTING', 'KRX-MARCAP', 'KRX-ADMINISTRATIVE'
#             'ETF/KR'
#     '''
#     market = market.upper()
#     if market in [ 'NASDAQ', 'NYSE', 'AMEX', 'SSE', 'SZSE', 'HKEX', 'TSE', 'HOSE']:
#         return NaverStockListing(market).read()
#     if market in [ 'KRX', 'KOSPI', 'KOSDAQ', 'KONEX']:
#         return KrxStockListing(market).read()
#     if market in [ 'KRX-DELISTING' ]:
#         return KrxDelisting(market).read()
#     if market in [ 'KRX-MARCAP' ]:
#         return KrxMarcapListing(market).read()
#     if market in [ 'KRX-ADMINISTRATIVE' ]:
#         return KrxAdministrative(market).read()
#     if market in [ 'S&P500', 'SP500']:
#         return WikipediaStockListing(market).read()
# ...

# %%
# 한국거래소 상장 종목 전체 가져오기
df_krx = fdr.StockListing('KRX')
df_krx.shape
# Out:
# (7104, 10)

# %%
df_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7104 entries, 0 to 7103
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          7104 non-null   object
#  1   Market          7104 non-null   object
#  2   Name            7104 non-null   object
#  3   Sector          2421 non-null   object
#  4   Industry        2402 non-null   object
#  5   ListingDate     2421 non-null   datetime64[ns]
#  6   SettleMonth     2421 non-null   object
#  7   Representative  2421 non-null   object
#  8   HomePage        2246 non-null   object
#  9   Region          2421 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 610.5+ KB

# %%
df_krx.describe()
# Out:
# <ipython-input-9-8453f2ac474b>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df_krx.describe()
#         Symbol Market             Name         Sector Industry  \
# count     7104   7104             7104           2421     2402
# unique    7104      3             7104            158     2250
# top     55FD47  KOSPI  한국FL17KOSPI200콜  특수 목적용 기계 제조업   기업인수합병
# freq         1   5459                1            142       36
# first      NaN    NaN              NaN            NaN      NaN
# last       NaN    NaN              NaN            NaN      NaN
#
#                 ListingDate SettleMonth Representative  \
# count                  2421        2421           2421
# unique                 1783           9           2307
# top     1976-06-30 00:00:00         12월              -
# ...

# %%
df_krx.to_csv("../rawdata/krx.csv", index=False)

# %%
pd.read_csv("../rawdata/krx.csv")
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 7099  000547   KOSPI  흥국화재2우B                       NaN
# 7100  000545   KOSPI    흥국화재우                       NaN
# 7101  003280   KOSPI     흥아해운                    해상 운송업
# 7102  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7103  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# ...
